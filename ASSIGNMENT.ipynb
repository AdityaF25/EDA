# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snn

# %%
df=pd.read_csv('/content/previous_application.csv')

# %%
df.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
# ...

# %%
df.tail()
# Out:
#         SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 357191     2717618      228166     Consumer loans     9091.395
# 357192     2102401      268025     Consumer loans    13173.795
# 357193     2792392      434236    Revolving loans     2250.000
# 357194     1127605      376364     Consumer loans     5636.340
# 357195     2526951      332581     Consumer loans    16667.865
#
#         AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 357191         138532.5    160474.5               0.0         138532.5
# 357192         193185.0    221818.5               0.0         193185.0
# 357193          45000.0     45000.0               NaN          45000.0
# 357194          81000.0     93829.5               0.0          81000.0
# 357195          84955.5     91125.0               0.0          84955.5
#
#        WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  ...  \
# 357191                     MONDAY                       21  ...
# ...

# %%
df.isnull()
# Out:
#         SK_ID_PREV  SK_ID_CURR  NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 0            False       False               False        False
# 1            False       False               False        False
# 2            False       False               False        False
# 3            False       False               False        False
# 4            False       False               False        False
# ...            ...         ...                 ...          ...
# 357191       False       False               False        False
# 357192       False       False               False        False
# 357193       False       False               False        False
# 357194       False       False               False        False
# 357195       False       False               False        False
#
#         AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 0                 False       False             False            False
# ...

# %%
df.sample(6)
# Out:
#         SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 222539     1175718      190628    Revolving loans     6300.000
# 271091     2549778      155732         Cash loans          NaN
# 211423     1126640      283184     Consumer loans     5437.035
# 250045     1294035      163630     Consumer loans    18901.530
# 83463      1803695      190614         Cash loans          NaN
# 115960     1710130      420192         Cash loans    11240.865
#
#         AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 222539             0.00     90000.0               NaN              NaN
# 271091             0.00         0.0               NaN              NaN
# 211423         45849.51     45346.5           4589.01         45849.51
# 250045        189000.00    170100.0          18900.00        189000.00
# 83463              0.00         0.0               NaN              NaN
# 115960        135000.00    170640.0               NaN        135000.00
#
# ...

# %%
df.dtypes
# Out:
# SK_ID_PREV                       int64
# SK_ID_CURR                       int64
# NAME_CONTRACT_TYPE              object
# AMT_ANNUITY                    float64
# AMT_APPLICATION                float64
# AMT_CREDIT                     float64
# AMT_DOWN_PAYMENT               float64
# AMT_GOODS_PRICE                float64
# WEEKDAY_APPR_PROCESS_START      object
# HOUR_APPR_PROCESS_START          int64
# FLAG_LAST_APPL_PER_CONTRACT     object
# NFLAG_LAST_APPL_IN_DAY           int64
# RATE_DOWN_PAYMENT              float64
# RATE_INTEREST_PRIMARY          float64
# RATE_INTEREST_PRIVILEGED       float64
# NAME_CASH_LOAN_PURPOSE          object
# NAME_CONTRACT_STATUS            object
# DAYS_DECISION                    int64
# NAME_PAYMENT_TYPE               object
# CODE_REJECT_REASON              object
# NAME_TYPE_SUITE                 object
# NAME_CLIENT_TYPE                object
# NAME_GOODS_CATEGORY             object
# NAME_PORTFOLIO                  object
# ...

# %%
df.isnull().any()
# Out:
# SK_ID_PREV                     False
# SK_ID_CURR                     False
# NAME_CONTRACT_TYPE             False
# AMT_ANNUITY                     True
# AMT_APPLICATION                False
# AMT_CREDIT                     False
# AMT_DOWN_PAYMENT                True
# AMT_GOODS_PRICE                 True
# WEEKDAY_APPR_PROCESS_START     False
# HOUR_APPR_PROCESS_START        False
# FLAG_LAST_APPL_PER_CONTRACT    False
# NFLAG_LAST_APPL_IN_DAY         False
# RATE_DOWN_PAYMENT               True
# RATE_INTEREST_PRIMARY           True
# RATE_INTEREST_PRIVILEGED        True
# NAME_CASH_LOAN_PURPOSE         False
# NAME_CONTRACT_STATUS           False
# DAYS_DECISION                  False
# NAME_PAYMENT_TYPE              False
# CODE_REJECT_REASON             False
# NAME_TYPE_SUITE                 True
# NAME_CLIENT_TYPE               False
# NAME_GOODS_CATEGORY            False
# NAME_PORTFOLIO                 False
# NAME_PRODUCT_TYPE              False
# ...

# %%
df.describe()
# Out:
#          SK_ID_PREV     SK_ID_CURR    AMT_ANNUITY  AMT_APPLICATION  \
# count  3.571960e+05  357196.000000  279181.000000     3.571960e+05
# mean   1.921435e+06  278536.292291   15699.241513     1.719463e+05
# std    5.332746e+05  102841.525757   14643.788210     2.878255e+05
# min    1.000001e+06  100001.000000       0.000000     0.000000e+00
# 25%    1.459141e+06  189517.000000    6219.135000     1.992600e+04
# 50%    1.921930e+06  278782.500000   11093.490000     7.055550e+04
# 75%    2.382924e+06  367836.000000   20247.975000     1.800000e+05
# max    2.845382e+06  456255.000000  417927.645000     4.005000e+06
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# count  3.571960e+05      1.705140e+05     2.766950e+05
# mean   1.921327e+05      6.692609e+03     2.220109e+05
# std    3.135867e+05      1.985263e+04     3.096089e+05
# min    0.000000e+00      0.000000e+00     0.000000e+00
# 25%    2.471850e+04      0.000000e+00     4.950000e+04
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 0          2030495      271877     Consumer loans     1730.430
# 1          2802425      108129         Cash loans    25188.615
# 2          2523466      122040         Cash loans    15060.735
# 3          2819243      176158         Cash loans    47041.335
# 4          1784265      202054         Cash loans    31924.395
# ...            ...         ...                ...          ...
# 357191     2717618      228166     Consumer loans     9091.395
# 357192     2102401      268025     Consumer loans    13173.795
# 357193     2792392      434236    Revolving loans     2250.000
# 357194     1127605      376364     Consumer loans     5636.340
# 357195     2526951      332581     Consumer loans    16667.865
#
#         AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 0               17145.0     17145.0               0.0          17145.0
# ...

# %%
df.var()
# Out:
# <ipython-input-22-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# SK_ID_PREV                   2.843818e+11
# SK_ID_CURR                   1.057638e+10
# AMT_ANNUITY                  2.144405e+08
# AMT_APPLICATION              8.284351e+10
# AMT_CREDIT                   9.833665e+10
# AMT_DOWN_PAYMENT             3.941267e+08
# AMT_GOODS_PRICE              9.585765e+10
# HOUR_APPR_PROCESS_START      1.110506e+01
# NFLAG_LAST_APPL_IN_DAY       3.656793e-03
# RATE_DOWN_PAYMENT            1.160924e-02
# RATE_INTEREST_PRIMARY        7.657605e-03
# RATE_INTEREST_PRIVILEGED     9.816837e-03
# DAYS_DECISION                6.143715e+05
# SELLERPLACE_AREA             1.370735e+08
# CNT_PAYMENT                  2.054172e+02
# ...

# %%
df.isnull().sum()
# Out:
# SK_ID_PREV                          0
# SK_ID_CURR                          0
# NAME_CONTRACT_TYPE                  0
# AMT_ANNUITY                     78015
# AMT_APPLICATION                     0
# AMT_CREDIT                          0
# AMT_DOWN_PAYMENT               186682
# AMT_GOODS_PRICE                 80501
# WEEKDAY_APPR_PROCESS_START          0
# HOUR_APPR_PROCESS_START             0
# FLAG_LAST_APPL_PER_CONTRACT         0
# NFLAG_LAST_APPL_IN_DAY              0
# RATE_DOWN_PAYMENT              186682
# RATE_INTEREST_PRIMARY          355897
# RATE_INTEREST_PRIVILEGED       355897
# NAME_CASH_LOAN_PURPOSE              0
# NAME_CONTRACT_STATUS                0
# DAYS_DECISION                       0
# NAME_PAYMENT_TYPE                   0
# CODE_REJECT_REASON                  0
# NAME_TYPE_SUITE                174749
# NAME_CLIENT_TYPE                    0
# NAME_GOODS_CATEGORY                 0
# NAME_PORTFOLIO                      0
# NAME_PRODUCT_TYPE                   0
# ...

# %%
df.skew()
# Out:
# <ipython-input-26-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# SK_ID_PREV                     0.000197
# SK_ID_CURR                    -0.004603
# AMT_ANNUITY                    2.739381
# AMT_APPLICATION                3.419291
# AMT_CREDIT                     3.293560
# AMT_DOWN_PAYMENT              26.246368
# AMT_GOODS_PRICE                3.107344
# HOUR_APPR_PROCESS_START       -0.023039
# NFLAG_LAST_APPL_IN_DAY       -16.415440
# RATE_DOWN_PAYMENT              2.099423
# RATE_INTEREST_PRIMARY          5.289604
# RATE_INTEREST_PRIVILEGED      -1.097877
# DAYS_DECISION                 -1.033328
# SELLERPLACE_AREA             334.977034
# CNT_PAYMENT                    1.573031
# DAYS_FIRST_DRAWING            -3.660125
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 357191    False
# 357192    False
# 357193    False
# 357194    False
# 357195    False
# Length: 357196, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['SK_ID_PREV', 'SK_ID_CURR', 'NAME_CONTRACT_TYPE', 'AMT_ANNUITY',
#        'AMT_APPLICATION', 'AMT_CREDIT', 'AMT_DOWN_PAYMENT', 'AMT_GOODS_PRICE',
#        'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START',
#        'FLAG_LAST_APPL_PER_CONTRACT', 'NFLAG_LAST_APPL_IN_DAY',
#        'RATE_DOWN_PAYMENT', 'RATE_INTEREST_PRIMARY',
#        'RATE_INTEREST_PRIVILEGED', 'NAME_CASH_LOAN_PURPOSE',
#        'NAME_CONTRACT_STATUS', 'DAYS_DECISION', 'NAME_PAYMENT_TYPE',
#        'CODE_REJECT_REASON', 'NAME_TYPE_SUITE', 'NAME_CLIENT_TYPE',
#        'NAME_GOODS_CATEGORY', 'NAME_PORTFOLIO', 'NAME_PRODUCT_TYPE',
#        'CHANNEL_TYPE', 'SELLERPLACE_AREA', 'NAME_SELLER_INDUSTRY',
#        'CNT_PAYMENT', 'NAME_YIELD_GROUP', 'PRODUCT_COMBINATION',
#        'DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE', 'DAYS_LAST_DUE_1ST_VERSION',
#        'DAYS_LAST_DUE', 'DAYS_TERMINATION', 'NFLAG_INSURED_ON_APPROVAL'],
#       dtype='object')

# %%
df.describe(include='all')
# Out:
#           SK_ID_PREV     SK_ID_CURR NAME_CONTRACT_TYPE    AMT_ANNUITY  \
# count   3.571960e+05  357196.000000             357196  279181.000000
# unique           NaN            NaN                  4            NaN
# top              NaN            NaN     Consumer loans            NaN
# freq             NaN            NaN             161050            NaN
# mean    1.921435e+06  278536.292291                NaN   15699.241513
# std     5.332746e+05  102841.525757                NaN   14643.788210
# min     1.000001e+06  100001.000000                NaN       0.000000
# 25%     1.459141e+06  189517.000000                NaN    6219.135000
# 50%     1.921930e+06  278782.500000                NaN   11093.490000
# 75%     2.382924e+06  367836.000000                NaN   20247.975000
# max     2.845382e+06  456255.000000                NaN  417927.645000
#
#         AMT_APPLICATION    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# ...

# %%
plt.figure(figsize=(10,5))
snn.histplot(df['AMT_ANNUITY'])
plt.show()

# %%
plt.figure(figsize=(20,10))
snn.histplot(df['AMT_GOODS_PRICE'])
plt.show()

# %%
snn.pairplot(df[['NAME_CASH_LOAN_PURPOSE','AMT_GOODS_PRICE']])
plt.show()
